# %%
import numpy as np
import pandas as pd
import sklearn
from xgboost import XGBRegressor
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Untitled spreadsheet - Final_form_data.csv")
tst_df = pd.read_csv("Untitled spreadsheet - Final_ex_Data.csv")

# %%
df.dtypes
# Out:
# pressure(bar)         float64
# heat flux(kW/m2)      float64
# mass fluxkg/(m2⋅s)    float64
# sub cooling           float64
# channel dia(mm)       float64
# d/dMax                float64
# t/tMax                float64
# dtype: object

# %%
df
# Out:
#        pressure(bar)  heat flux(kW/m2)  mass fluxkg/(m2⋅s)  sub cooling  \
# 0               1.11             173.0               495.0          6.5
# 1               1.11             173.0               495.0          6.5
# 2               1.11             173.0               495.0          6.5
# 3               1.11             173.0               495.0          6.5
# 4               1.11             173.0               495.0          6.5
# ...              ...               ...                 ...          ...
# 14356           4.06             123.0               762.0          4.4
# 14357           4.06             123.0               762.0          4.4
# 14358           4.06             123.0               762.0          4.4
# 14359           4.06             123.0               762.0          4.4
# 14360           4.06             123.0               762.0          4.4
#
#        channel dia(mm)    d/dMax    t/tMax
# 0               13.330  0.154977  0.004673
# ...

# %%
df.dropna(inplace=True)

# %%
tst_df.dropna(inplace=True)

# %%
m1 = Lasso(alpha=0.1)

# %%
x_tr = df.drop("d/dMax", axis=1)
y_tr = df["d/dMax"]
x_ts = tst_df.drop("d/dMax", axis=1)
y_ts = tst_df["d/dMax"]

# %%
m1.fit(x_tr, y_tr)
# Out:
# Lasso(alpha=0.1)

# %%
m1.score(x_ts, y_ts)
# Out:
# -0.09827249875128041

# %%
m2 = KNeighborsRegressor(n_neighbors=2)

# %%
m2.fit(x_tr, y_tr)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
m2.score(x_ts, y_ts)
# Out:
# -0.1000263560617558

# %%
m3 = RandomForestRegressor(n_estimators=100)

# %%
m3.fit(x_tr, y_tr)
# Out:
# RandomForestRegressor()

# %%
m3.score(x_ts, y_ts)
# Out:
# -0.08795242674997206

# %%
m4 = XGBRegressor()

# %%
m4.fit(x_tr, y_tr)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
m4.score(x_ts, y_ts)
# Out:
# -0.08102330240191202

# %%
bm_df1 = pd.read_csv("BubbleGrowth_vs_Time.xlsx - vibhav 2.csv")

bm_df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 bm_df1 = pd.read_csv("BubbleGrowth_vs_Time.xlsx - vibhav 2.csv")
#       3 bm_df1
#
# ...

# %%
bm_df1.drop(["run", "fluid", "flow/pool", "diameter(mm)", "time(ms)", "dMax", "tMax"], axis=1, inplace = True)

# %%
bm_df1

# %%
bm1 = bm_df1[:214]
bm2 = bm_df1[1111:1208]

# %%
bm_df2 = pd.read_csv("BubbleGrowth_vs_Time.xlsx - vibhav 3.csv")

# %%
bm_df2.drop(["run", "fluid", "flow/pool", "diameter(mm)", "time(ms)", "dMax", "tMax"], axis=1, inplace = True)

# %%
bm_df2

# %%
bm_df2 = bm_df2[1559:1745]

# %%
bm_df3 = pd.read_csv("BubbleGrowth_vs_Time.xlsx - vibhav 4.csv")

# %%
bm_df3.drop(["run", "fluid", "flow/pool"], axis=1, inplace = True)

# %%
bm_df3 = bm_df3[:44]

# %%
bm_df3

# %%
xa1 = np.array(bm1["t/tMax"])
ya1 = np.array(bm1["d/dMax"])
xa2 = np.array(bm_df2["t/tMax"])
ya2 = np.array(bm_df2["d/dMax"])
xa3 = np.array(bm_df3["t/tMax"])
ya3 = np.array(bm_df3["d/dMax"])
xa4 = np.array(bm2["t/tMax"])
ya4 = np.array(bm2["d/dMax"])

# %%
plt.plot(xa1, ya1)
plt.plot(xa2, ya2)
plt.plot(xa3, ya3)
# plt.plot(xa4, ya4)
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import sklearn
from xgboost import XGBRegressor
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df_ex = pd.read_csv("mix data.csv")

df_ex
# Out:
#        pressure(bar)  heat flux(kW/m2)  mass fluxkg/(m2⋅s)  sub cooling  \
# 0               1.11           173.000               495.0          6.5
# 1               1.11           173.000               495.0          6.5
# 2               1.11           173.000               495.0          6.5
# 3               1.11           173.000               495.0          6.5
# 4               1.11           173.000               495.0          6.5
# ...              ...               ...                 ...          ...
# 16609           1.00             0.045                30.0         24.0
# 16610           1.00             0.045                30.0         24.0
# 16611           1.00             0.045                30.0         24.0
# 16612           1.00             0.045                30.0         24.0
# 16613           1.00             0.045                30.0         24.0
#
#        channel dia(mm)    d/dMax    t/tMax
# 0                13.33  0.154977  0.004673
# ...

# %%
df_ex.dropna(inplace=True)

# %%
xe = df_ex.drop("d/dMax", axis=1)
ye = df_ex["d/dMax"]

# %%
# np.random.seed(42)

x_tre, x_tse, y_tre, y_tse = train_test_split(xe, ye, train_size=0.85)

# %%
o_m_ex = XGBRegressor()

# %%
param_grid = {
    'n_estimators': [100, 300],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    'subsample': [0.5, 0.7],
    'colsample_bytree': [0.5, 0.7],
    'gamma': [0, 0.1]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
o_m_ex.fit(x_tre, y_tre)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
m_ex = GridSearchCV(o_m_ex , param_grid , cv = 2 , verbose = 2)
m_ex.fit(x_tre, y_tre)
# %timeit
# Out:
# Fitting 2 folds for each of 288 candidates, totalling 576 fits
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=300, subsample=0.5; total time=   0.2s
# ...

# %%
count = 0
x = 0
for i in xe["t/tMax"]:
    x = x+1
    if i == 1:
        print(x)
        count = count+ 1
        if count == 5:
            break
# Out:
# 214
# 453
# 680
# 1018
# 1078

# %%
m_ex.get_params()
# Out:
# {'cv': 2,
#  'error_score': nan,
#  'estimator__objective': 'reg:squarederror',
#  'estimator__base_score': None,
#  'estimator__booster': None,
#  'estimator__callbacks': None,
#  'estimator__colsample_bylevel': None,
#  'estimator__colsample_bynode': None,
#  'estimator__colsample_bytree': None,
#  'estimator__device': None,
#  'estimator__early_stopping_rounds': None,
#  'estimator__enable_categorical': False,
#  'estimator__eval_metric': None,
#  'estimator__feature_types': None,
#  'estimator__gamma': None,
#  'estimator__grow_policy': None,
#  'estimator__importance_type': None,
#  'estimator__interaction_constraints': None,
#  'estimator__learning_rate': None,
#  'estimator__max_bin': None,
#  'estimator__max_cat_threshold': None,
#  'estimator__max_cat_to_onehot': None,
#  'estimator__max_delta_step': None,
#  'estimator__max_depth': None,
#  'estimator__max_leaves': None,
#  'estimator__min_child_weight': None,
#  'estimator__missing': nan,
# ...

# %%
testingx1 = xe[:213]
testingy1 = ye[:213]
testingx2 = xe[214:452]
testingy2 = ye[214:452]
testingx3 = xe[453:679]
testingy3 = ye[453:679]
testingx4 = xe[680:1017]
testingy4 = ye[680:1017]
testingx5 = xe[1018:1078]
testingy5 = ye[1018:1078]

# %%
yp1 = m2.predict(testingx1)
yp2 = m2.predict(testingx2)
yp3 = m2.predict(testingx3)
yp4 = m2.predict(testingx4)
yp5 = m2.predict(testingx5)

# %%
plt.plot(np.linspace(0, 1, len(yp1)), yp1, label = "Predicted Diameter")
plt.plot(np.linspace(0, 1, len(yp1)), testingy1, label = "True Diameter")
plt.legend()
plt.xlabel("Time")
plt.ylabel("Diameter")
plt.title("True and Predicted Diameters")
plt.grid(True)
plt.show()

# %%
plt.scatter(testingy1, yp1, label = "Plot")
plt.xlabel('True Diameter')
plt.ylabel('Predicted Diameter')
plt.plot(np.linspace(0, 1), np.linspace(0, 1), color = "orange", label = "x = y")
plt.legend()
plt.title('Predicted vs True Diameter')
plt.show()

# %%
plt.plot(np.linspace(0, 1, len(yp2)), yp2, label = "Predicted Diameter")
plt.plot(np.linspace(0, 1, len(yp2)), testingy2, label = "True Diameter")
plt.legend()
plt.xlabel("Time")
plt.ylabel("Diameter")
plt.title("True and Predicted Diameters")
plt.grid(True)
plt.show()

# %%
plt.scatter(testingy2, yp2, label = "Plot")
plt.xlabel('True Diameter')
plt.ylabel('Predicted Diameter')
plt.plot(np.linspace(0, 1), np.linspace(0, 1), color = "orange", label = "x = y")
plt.legend()
plt.title('Predicted vs True Diameter')
plt.show()

# %%
plt.plot(np.linspace(0, 1, len(yp3)), yp3, label = "Predicted Diameter")
plt.plot(np.linspace(0, 1, len(yp3)), testingy3, label = "True Diameter")
plt.legend()
plt.xlabel("Time")
plt.ylabel("Diameter")
plt.title("True and Predicted Diameters")
plt.grid(True)
plt.show()

# %%
plt.scatter(testingy3, yp3, label = "Plot")
plt.xlabel('True Diameter')
plt.ylabel('Predicted Diameter')
plt.plot(np.linspace(0, 1), np.linspace(0, 1), color = "orange", label = "x = y")
plt.legend()
plt.title('Predicted vs True Diameter')
plt.show()

# %%
plt.plot(np.linspace(0, 1, len(yp4)), yp4, label = "Predicted Diameter")
plt.plot(np.linspace(0, 1, len(yp4)), testingy4, label = "True Diameter")
plt.legend()
plt.xlabel("Time")
plt.ylabel("Diameter")
plt.title("True and Predicted Diameters")
plt.grid(True)
plt.show()

# %%
plt.scatter(testingy4, yp4, label = "Plot")
plt.xlabel('True Diameter')
plt.ylabel('Predicted Diameter')
plt.plot(np.linspace(0, 1), np.linspace(0, 1), color = "orange", label = "x = y")
plt.legend()
plt.title('Predicted vs True Diameter')
plt.show()

# %%
plt.plot(np.linspace(0, 1, len(yp5)), yp5, label = "Predicted Diameter")
plt.plot(np.linspace(0, 1, len(yp5)), testingy5, label = "True Diameter")
plt.legend()
plt.xlabel("Time")
plt.ylabel("Diameter")
plt.title("True and Predicted Diameters")
plt.grid(True)
plt.show()

# %%
plt.scatter(testingy5, yp5, label = "Plot")
plt.xlabel('True Diameter')
plt.ylabel('Predicted Diameter')
plt.plot(np.linspace(0, 1), np.linspace(0, 1), color = "orange", label = "x = y")
plt.legend()
plt.title('Predicted vs True Diameter')
plt.show()
